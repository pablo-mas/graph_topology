# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Example of morphological file
df = pd.read_csv("/home/pablo/code/aramis/graph_topology/results/exp1_t0.5_d0/csv/morphology/morphology_sample1.csv")
df
# Out:
#      centroid-0    centroid-1  area   perimeter  area_bbox  area_convex  \
# 0   5428.872081  10152.001062  1884  264.717821       3843         2425
# 1   5410.917485  10219.508841   509   93.396970        768          555
# 2   5409.160194  10123.902913   206   56.083261        306          214
# 3   5490.517281  10138.255760   868  120.953319       1247          918
# 4   5399.379639  10388.760339   943  121.681241       1365          987
# 5   5422.942857  10374.504762   105   38.526912        182          111
# 6   5462.320210  10484.354331   381   91.053824        754          442
# 7   5476.984848  10443.634199   462  106.024387        870          556
# 8   5486.962190  10381.116037   767  106.225397        990          788
# 9   5492.455882  10488.995098   204   54.769553        300          216
# 10  5388.683478  10738.986087   575   95.154329        784          609
# 11  5436.728522  10710.690722   582   93.396970        783          614
# ...

# %%
# Example of topological file
df = pd.read_csv("/home/pablo/code/aramis/graph_topology/results/exp1_t0.5_d0/csv/topology/topology_exp1_t0.5_d0.csv")
df
# Out:
#    order  size  diameter  radius  average_shortest_path_length   density  \
# 0     24    50         9       5                      3.282609  0.181159
# 1     40    91        10       5                      3.958974  0.116667
# 2      9    13         4       2                      2.027778  0.361111
#
#    graph_clique_number  graph_number_of_cliques  transitivity  \
# 0                    3                       27      0.450000
# 1                    4                       49      0.430851
# 2                    3                        6      0.500000
#
#    local_efficiency  ...  closeness_centrality_min  closeness_centrality_max  \
# 0          0.753697  ...                  0.207207                  0.403509
# 1          0.718621  ...                  0.176471                  0.348214
# 2          0.645370  ...                  0.347826                  0.666667
#
#    closeness_centrality_qt95  closeness_centrality_qt75  \
# ...
